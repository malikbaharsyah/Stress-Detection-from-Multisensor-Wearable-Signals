# %%
import neurokit2 as nk
import numpy as np
import pandas as pd
import os

# %%
base_foler = "D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset"

# %%
data_all = [path for path in os.listdir(base_foler)]
data_all.remove("SurveyResults.xlsx")
data_all.sort()
# save data_all to a csv file
data_all = pd.DataFrame(data_all, columns=["filename"])
data_all.to_csv("data_all.csv", index=False)

# %%
subjects = [path.split("_")[0] for path in os.listdir(base_foler)]
subjects = list(set(subjects))
subjects.remove("SurveyResults.xlsx")
print(f"Found {len(subjects)} Subjects: {subjects}")
# Out:
# Found 15 Subjects: ['6B', '7A', 'F5', '8B', 'CE', '15', '5C', '94', '7E', '6D', '83', 'E4', 'BG', 'DF', 'EG']

# %%
# get the list of all files in the directory
files = os.listdir(base_foler)
# get folders that starts with "5C"
# folders = [f for f in files if f.startswith("5C")]
# folders.sort()
# bvp_paths = [os.path.join(base_foler, f, "BVP.csv") for f in folders]
# eda_paths = [os.path.join(base_foler, f, "EDA.csv") for f in folders]
# hr_paths = [os.path.join(base_foler, f, "HR.csv") for f in folders]
# ibi_paths = [os.path.join(base_foler, f, "IBI.csv") for f in folders]


# subject_folders format [{"ID": {subject_id}, "folders" : [folder1, folder2, ...]}]
subject_folders = []
for subject in subjects:
    # get all folders that starts with the subject id
    folders = [f for f in files if f.startswith(subject)]
    # sort the folders
    folders.sort()
    # add to the list
    subject_folders.append({"ID": subject, "folders": folders})

# len(subject_folders)
bvp_subject_paths = []
eda_subject_paths = []
hr_subject_paths = []
ibi_subject_paths = []
for subject_folder in subject_folders:
    subject_id = subject_folder["ID"]
    # get the list of all folders for this subject
    folders = subject_folder["folders"]
    # get the paths for each folder
    bvp_paths = [os.path.join(base_foler, f, "BVP.csv") for f in folders]
    eda_paths = [os.path.join(base_foler, f, "EDA.csv") for f in folders]
    hr_paths = [os.path.join(base_foler, f, "HR.csv") for f in folders]
    ibi_paths = [os.path.join(base_foler, f, "IBI.csv") for f in folders]

    bvp_subject_paths.append({"ID": subject_id, "paths": bvp_paths})
    eda_subject_paths.append({"ID": subject_id, "paths": eda_paths})
    hr_subject_paths.append({"ID": subject_id, "paths": hr_paths})
    ibi_subject_paths.append({"ID": subject_id, "paths": ibi_paths})

# %%
bvp_subject_paths[0]
# Out:
# {'ID': '6B',
#  'paths': ['D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1587569373\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1587585327\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1587653438\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1587661095\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1587662477\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1588961203\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1588970444\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1589052301\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1589901451\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1590172247\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1590239123\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1592925729\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1592996203\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593024104\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593083317\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593086670\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593091155\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593101741\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593110897\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593168956\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593176942\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593191957\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593427701\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593437366\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593446044\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593455714\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593514692\\BVP.csv',
#   'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593535767\\BVP.csv']}

# %%
# loop through each files
# gather all the data into a single dataframe
def gather_data(subject_paths, data_type, output_dir="processed"):
    os.makedirs(output_dir, exist_ok=True)

    for subject in subject_paths:
        subject_id = subject["ID"]
        paths = subject["paths"]
        output_path = os.path.join(output_dir, f"{subject_id}_{data_type}.csv")
        # check if the file already exists
        if os.path.exists(output_path):
            print(f"File {output_path} already exists, skipping...")
            continue
        # create an empty dataframe
        df = pd.DataFrame()
        # loop through each path
        for path in paths:
            # read the data
            data = pd.read_csv(path)
            # check if the data is empty
            if data.empty:
                print(f"File {path} is empty, skipping...")
                continue
            # check if the data has the same columns
            if df.empty:
                df = data
            else:
                if not df.columns.equals(data.columns):
                    print(f"File {path} has different columns, skipping...")
                    continue
                # concatenate the data
                df = pd.concat([df, data], ignore_index=True)

# gather the data for each type
# gather_data(bvp_subject_paths, "BVP")
# gather_data(eda_subject_paths, "EDA")
# gather_data(hr_subject_paths, "HR")
# gather_data(ibi_subject_paths, "IBI")

# %%
def segment_signal(signal, sampling_rate, window_sec, overlap):
    window_size = int(sampling_rate * window_sec)
    step_size = int(window_size * (1 - overlap))
    
    segments = []
    starts = []

    for start in range(0, len(signal) - window_size + 1, step_size):
        end = start + window_size
        segments.append(signal[start:end])
        starts.append(start / sampling_rate)  # time in seconds
    print(f"Segmented signal into {len(segments)} segments of {window_sec} seconds each")
    return segments, starts

# %%
def label_bvp(bvp_path, window_sec=10, overlap=0.5, survey_labeled=None):
    # load bvp signal
    # filename = os.path.basename(bvp_path)
    parent_folder = os.path.dirname(bvp_path)
    filename = os.path.basename(parent_folder)
    bvp_raw = pd.read_csv(bvp_path, header=None)
    # check if the data is empty
    if bvp_raw.empty:
        print(f"File {bvp_path} is empty, skipping...")
        return
    start_time = bvp_raw.iloc[0, 0]
    sample_rate = bvp_raw.iloc[1, 0]
    signal = bvp_raw.iloc[2:, 0].values
    print(f"Loaded {len(signal)} samples from {bvp_path}")
    # segmentation
    segments, start_times = segment_signal(signal, sample_rate, window_sec, overlap)
    # print(f"Segmented into {len(segments)} windows of {window_sec}s each")
    # feature extraction
    features_list = []
    for i, seg in enumerate(segments):
        try:
            signals, info = nk.ppg_process(seg, sampling_rate=sample_rate)
            features = nk.hrv_time(signals, sampling_rate=sample_rate, show=False)
            features["window_start_sec"] = start_times[i]
            features["start_unix"] = start_time + start_times[i]
            features["end_unix"] = start_time + start_times[i] + window_sec
            features_list.append(features)
        except Exception as e:
            print(f"Skipping window {i} due to error: {e}")
    print(f"Extracted {len(features_list)} windows from {filename}")
    features_df = pd.concat(features_list, ignore_index=True)
    # add label
    features_df["label"] = None
    for i, row in features_df.iterrows():
        for j, survey_row in survey_labeled.iterrows():
            if row["start_unix"] >= survey_row["Start_unix"] and row["end_unix"] <= survey_row["End_unix"]:
                features_df.at[i, "label"] = survey_row["Stress level"]
                break
    # save to csv
    output_path = os.path.join("processed", f"BVP_{filename}.csv")
    features_df.to_csv(output_path, index=False)
    print(f"Saved {len(features_df)} rows to {output_path}")

# %%
len(bvp_subject_paths)
all_bvp_paths = []
for subject in bvp_subject_paths:
    paths = subject["paths"]
    for path in paths:
        all_bvp_paths.append(path)

# %%
all_bvp_paths.sort()
all_bvp_paths
# Out:
# ['D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1594140175\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1594149654\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1594213322\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1594220239\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1594238057\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1594298975\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1594311202\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1594325201\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1594378283\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1594380033\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595334888\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595347920\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595360012\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595425036\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595433234\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595446619\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595592772\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595600598\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595604812\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595608145\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595854651\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595857850\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595862148\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595866250\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595869772\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595871983\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595940277\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595947283\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595953571\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1595970459\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596027852\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596037241\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596204744\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596219716\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596222922\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596546369\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596547439\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596551659\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596564517\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596634348\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596636683\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596648020\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\15_1596653112\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1586886626\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1586886712\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1587297777\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1587336033\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1587338580\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1587569014\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1587593082\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1587593875\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1587649438\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1587661745\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1587674047\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1588974475\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1589028738\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1589199819\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1589199875\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1589286789\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1589298448\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1589803857\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1589889161\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1592925628\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1592925705\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1592926305\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1593006542\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1593018203\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1593018622\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\5C_1593094946\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1587569373\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1587585327\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1587653438\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1587661095\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1587662477\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1588961203\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1588970444\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1589052301\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1589901451\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1590172247\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1590239123\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1592925729\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1592996203\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593024104\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593083317\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593086670\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593091155\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593101741\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593110897\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593168956\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593176942\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593191957\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593427701\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593437366\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593446044\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593455714\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593514692\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6B_1593535767\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6D_1594751512\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6D_1594757863\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6D_1594831043\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6D_1594910470\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6D_1594998483\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6D_1595252734\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6D_1595339521\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6D_1595523837\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\6D_1595604487\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1587212302\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1587228286\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1587298286\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1587326219\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1587556854\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1587583295\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1587643240\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1587734399\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1588977047\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1589022077\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1589025873\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1589055551\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1589141032\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1592752730\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1592925663\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1592926011\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1592926372\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1592933285\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1592941276\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593091052\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593101633\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593104418\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593115159\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593177044\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593192268\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593203567\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593436174\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593439820\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593450967\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593521778\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593527735\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593534070\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593547182\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593551081\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593609973\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593620516\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593624975\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593633083\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593637327\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593696872\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593701029\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593708143\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1593709119\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1594043417\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1594061634\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1594068355\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7A_1594128392\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603292452\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603309557\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603314547\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603321625\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603327234\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603373768\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603406377\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603409208\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603719136\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603737490\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603746501\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603808368\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1603834287\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604073279\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604086539\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604104386\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604146270\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604174806\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604508455\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604522224\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604541335\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604587428\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604935657\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1604965789\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1605285176\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1605305267\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1605315982\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\7E_1605889226\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1603929757\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1603966680\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604016419\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604103283\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604147386\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604190038\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604214785\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604224222\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604278781\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604314003\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604538637\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604565269\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604589439\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604630543\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604658728\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1604666276\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605230607\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605254008\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605262502\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605317390\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605336146\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605401907\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605422619\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605428200\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605438437\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605488271\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1605522674\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1607582006\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1607590102\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1607649094\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1607663116\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1607735993\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1607755141\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1607769127\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1607822759\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1607908668\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1607944061\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1608176003\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1608196385\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1608203746\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1608272959\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1608296659\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1608862601\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1608887726\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1608947368\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\83_1608955073\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594138963\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594153037\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594225495\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594300582\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594300904\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594313953\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594320348\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594328622\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594644905\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594674624\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594731698\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594757712\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594763406\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594816490\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594818336\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594831573\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594848059\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594904937\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594914137\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594927003\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1594993425\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1595015366\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1595252880\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1595262366\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1595277964\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1595437580\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1595450243\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1595523613\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1595530690\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\8B_1595538351\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587166335\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587167248\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587209323\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587293342\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587305684\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587310570\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587312802\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587314078\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587319047\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587327523\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1587334951\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1588544695\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1588544895\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1589039387\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1589050691\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1589051482\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1589152557\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1589200299\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1589211970\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1589228684\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1589282081\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1592752519\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1592752658\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1592925429\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1592929503\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1592936512\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1592942711\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1592945172\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593002737\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593006245\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593009834\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593014546\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593019043\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593021522\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593029038\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593091230\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593092855\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593098565\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593107532\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593110482\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593113840\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593115664\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593116487\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593118700\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593175365\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593182334\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593434552\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593436507\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593441535\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593443104\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593443279\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593446429\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593451003\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593453273\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593454489\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593458351\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593523361\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593608450\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593611980\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593623016\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593635623\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593694830\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593703320\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593710745\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1593720218\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1594125017\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\94_1594129474\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603671305\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603681317\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603685056\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603692429\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603693197\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603693561\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603929535\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603929659\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603933213\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603934355\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603944938\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603950453\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603951073\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1603952237\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604018298\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604018860\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604020604\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604026527\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604028580\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604029600\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604032944\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604036907\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604037255\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604041261\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604043352\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604046977\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604196392\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604197220\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604211037\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604212249\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604569017\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604624541\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604625917\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604637443\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604640819\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604641179\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604646790\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604652152\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604652324\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1604654730\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605144876\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605162029\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605168600\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605177819\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605182166\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605240943\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605241050\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605241814\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605246857\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605406957\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605407143\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605407666\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1605417734\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1606958133\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1606959940\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1606972127\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1606972651\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1606973939\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1606976272\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1606983743\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1606985234\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1606987563\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607043192\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607045808\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607131158\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607144946\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607147439\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607150884\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607215814\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607218219\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607219762\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607229325\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607229558\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607232172\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607561446\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607576785\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607585026\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607648493\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607652757\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607664323\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607672427\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607673482\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607676959\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607681888\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607735684\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607751901\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607752220\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607755833\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607760334\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\BG_1607770986\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1586788313\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1587567895\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1587568353\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1587640779\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1587646985\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1587647855\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1587660308\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1587687471\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1588162715\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1588172175\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1588189759\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1588205936\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1588536145\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1588548635\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1588972583\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1588981607\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1588981804\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589026517\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589034718\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589052103\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589052154\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589113933\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589202513\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589216580\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589228164\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589292074\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589831911\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1589901374\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1590172162\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1590237729\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1592752859\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1592925596\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593004524\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593023688\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593088528\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593106218\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593183121\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593437835\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593536265\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593632057\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593694242\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593697107\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1593783290\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1594059133\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\CE_1594129814\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1594231189\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1594296700\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1594305457\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1594385893\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1594662154\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1594757884\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1594907019\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1594991923\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1595273281\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1595337957\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1595429921\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1595512329\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1595526948\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1595617578\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1595854003\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1595941102\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1596031340\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1596114677\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1596205551\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1596476007\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1596543989\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1596630398\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1596719209\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1596735393\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1596802799\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\DF_1596814961\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587206108\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587236732\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587241555\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587294299\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587298478\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587302737\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587312370\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587315090\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587318394\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587324331\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587329010\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587383217\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587393366\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587409032\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587409707\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1587417188\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1588984019\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589028644\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589028974\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589051416\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589113150\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589200218\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589306182\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589306729\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589312746\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589802835\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589811508\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589839893\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589889235\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1589917617\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1590149482\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1592752787\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1592937530\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1592937902\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1592938003\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1592939478\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1592945524\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593002275\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593015418\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593021695\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593104925\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593439701\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593461673\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593538007\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593543088\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593551794\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593612140\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593624124\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593630180\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593711228\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593726493\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593786145\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1593809250\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1594043080\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1594049696\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1594051892\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\E4_1594057956\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1603463571\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1603543833\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1603574437\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1603574790\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1603627843\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1603884903\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1603895434\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1603931405\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1603972494\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1603993236\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1604323585\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1604342951\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1604767157\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1604840929\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1605101659\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1605118411\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1605118579\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1605186788\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1605533971\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1605625156\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1605881234\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1605972254\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1606052378\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1606762920\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1607528704\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1607559497\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1607606863\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1607634439\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1607644800\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1607959367\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1608048804\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\EG_1608049371\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594141473\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594217466\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594218280\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594223270\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594235058\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594390055\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594402134\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594403655\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594647650\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594671025\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594746945\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594758671\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594820907\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594825280\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594830652\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594843057\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594920460\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594927034\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594932553\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594934714\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594934801\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1594996818\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595014348\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595254546\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595272717\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595337790\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595344020\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595351362\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595358823\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595421778\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595438005\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595439251\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595514881\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595515035\\BVP.csv',
#  'D:\\Kuliah\\TA\\Dataset\\Multimodal\\dataset\\F5_1595533978\\BVP.csv']

# %%
len(all_bvp_paths)
print(all_bvp_paths[0])
bvp_raw = pd.read_csv(all_bvp_paths[2], header=None)
# Out:
# D:\Kuliah\TA\Dataset\Multimodal\dataset\15_1594140175\BVP.csv

# %%
survey_labeled = pd.read_csv("survey_labeled.csv")
survey_labeled["Stress level"].value_counts()
# Out:
# Stress level
# 2    179
# 0     46
# 1     20
# Name: count, dtype: int64

# %%
label_bvp(all_bvp_paths[0], survey_labeled=survey_labeled, window_sec=10, overlap=0.5)
# Out:
# Loaded 499631 samples from D:\Kuliah\TA\Dataset\Multimodal\dataset\15_1594140175\BVP.csv
# Segmented signal into 1560 segments of 10 seconds each
# c:\Users\malik\anaconda3\Lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# Skipping window 1227 due to error: cannot convert float NaN to integer
# Extracted 1559 windows from 15_1594140175
# [   HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  774.147727  302.767479         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  507.944694  535.258569  ...     1078.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN   HRV_HTI  HRV_TINN  \
# 0  81.818182  81.818182    515.625   1328.125  3.666667     31.25
#
#    window_start_sec    start_unix      end_unix
# 0               0.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0      893.75  460.800651         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  728.329132  768.811573  ...     1240.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       90.0       90.0      312.5     1812.5      5.0   234.375
#
#    window_start_sec    start_unix      end_unix
# 0               5.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  830.965909  375.703649         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  457.361659  471.162772  ...       1187.5
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  81.818182  81.818182      312.5   1453.125     11.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0              10.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  645.432692  219.898826         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  317.217004  329.126808  ...      853.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN   HRV_HTI  HRV_TINN  \
# 0  84.615385  84.615385      312.5    1031.25  4.333333     187.5
#
#    window_start_sec    start_unix      end_unix
# 0              15.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  710.336538  280.932647         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  399.43197  416.305478  ...      965.625  84.615385
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  92.307692    421.875   1328.125      6.5     93.75              20.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  729.166667  300.872705         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  379.851431  396.041985  ...      965.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       75.0  91.666667    421.875    1406.25     12.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0              25.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0     790.625  360.33236         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  504.778597  529.511043  ...     1046.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       90.0       90.0    421.875     1500.0      5.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0              30.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],     HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1056.640625  362.028008         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  409.924999  415.012528  ...     1384.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       75.0       87.5    421.875   1421.875      8.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0              35.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],     HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1091.796875  393.46623         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  455.543117  489.674352  ...     1409.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       75.0       87.5    578.125    1718.75      8.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0              40.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    870.3125  252.058582         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  402.223637  425.842965  ...      990.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       70.0       80.0      500.0   1359.375     10.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0              45.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  674.278846  216.773638         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  288.534146  299.282503  ...      915.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  61.538462  61.538462      375.0    984.375      6.5      62.5
#
#    window_start_sec    start_unix      end_unix
# 0              50.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  740.885417  266.62232         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  345.777851  362.627329  ...      978.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  83.333333  83.333333      375.0    1156.25     12.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0              55.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  723.557692  314.213053         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  378.644401  390.717319  ...     1040.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  92.307692  92.307692    328.125     1250.0      6.5     125.0
#
#    window_start_sec    start_unix      end_unix
# 0              60.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  744.791667  319.407559         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  416.580839  435.05812  ...      1043.75  91.666667
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  91.666667    328.125     1250.0      6.0       0.0              65.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    876.5625  335.155339         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  400.70332  424.68681  ...     1184.375       70.0
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0       70.0    328.125     1312.5     10.0       0.0              70.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    910.9375  296.010254         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  388.815252  412.298062  ...     1221.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       80.0       80.0      500.0     1312.5      5.0   359.375
#
#    window_start_sec    start_unix      end_unix
# 0              75.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  816.761364  297.539627         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  328.496813  341.70795  ...     1015.625  81.818182
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  90.909091    328.125   1203.125      5.5       0.0              80.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  728.365385  274.480041         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  388.143157  401.917733  ...      978.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  92.307692  92.307692    328.125   1203.125     13.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0              85.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  776.988636  204.214734         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  326.820323  344.305895  ...      984.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  90.909091  90.909091      375.0   1046.875      5.5   609.375
#
#    window_start_sec    start_unix      end_unix
# 0              90.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],     HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1056.640625  427.658562         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  616.600931  662.816145  ...     1328.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       87.5       87.5      562.5   1859.375      4.0   421.875
#
#    window_start_sec    start_unix      end_unix
# 0              95.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    1015.625  466.400361         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  731.543744  779.864843  ...     1371.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  77.777778  77.777778      562.5   1859.375      9.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             100.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  717.447917  91.463192         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  147.556446  154.751336  ...      715.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  16.666667  33.333333     656.25     1000.0      3.0    46.875
#
#    window_start_sec    start_unix      end_unix
# 0             105.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN  HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  705.729167  43.60433         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  77.554737  81.217214  ...       731.25       50.0
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  58.333333      625.0     781.25      4.0    78.125             110.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN  HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  720.052083  39.10982         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN   62.32219  64.526796  ...        750.0  33.333333
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  91.666667    640.625     781.25      4.0   109.375             115.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  700.520833  24.780046         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  29.420902  30.531513  ...      715.625   8.333333
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  41.666667    671.875      750.0      3.0     31.25             120.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  740.885417  180.437335         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  276.715337  290.206199  ...      878.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  41.666667  41.666667     406.25   1109.375      4.0   265.625
#
#    window_start_sec    start_unix      end_unix
# 0             125.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  740.885417  211.261676         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  329.104329  344.536806  ...      934.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  58.333333  91.666667     406.25     1125.0      6.0   265.625
#
#    window_start_sec    start_unix      end_unix
# 0             130.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  678.571429  155.49267         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  229.68055  236.290251  ...        787.5  71.428571
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN   HRV_HTI  HRV_TINN  window_start_sec  \
# 0  92.857143    421.875      937.5  4.666667     250.0             135.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  680.288462  145.686596         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  225.662725  235.033009  ...        787.5
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN   HRV_HTI  HRV_TINN  \
# 0  69.230769  69.230769    421.875     906.25  4.333333   265.625
#
#    window_start_sec    start_unix      end_unix
# 0             140.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  772.135417  235.881365         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  385.53502  404.327839  ...        862.5       75.0
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0       75.0      500.0    1343.75      6.0     187.5             145.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  741.477273  131.911213         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  233.801381  246.178474  ...      765.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  54.545455  72.727273    578.125    1093.75      5.5   140.625
#
#    window_start_sec    start_unix      end_unix
# 0             150.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    910.9375  290.833072         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  378.527965  401.489536  ...       1100.0
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       70.0       80.0      687.5   1546.875      5.0     31.25
#
#    window_start_sec    start_unix      end_unix
# 0             155.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],     HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1013.392857  226.145192         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  385.011752  418.26192  ...       1212.5  85.714286
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  85.714286     718.75     1312.5      3.5    343.75             160.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  771.306818  142.053977         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  224.804603  234.664173  ...       843.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  63.636364  72.727273     531.25     1062.5      5.5   234.375
#
#    window_start_sec    start_unix      end_unix
# 0             165.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  779.829545  127.791973         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  225.617642  237.679254  ...       843.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  72.727273  81.818182     593.75     1062.5      5.5   234.375
#
#    window_start_sec    start_unix      end_unix
# 0             170.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  751.302083  101.798967         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  169.665551  177.790755  ...      840.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  66.666667  83.333333    609.375     906.25      6.0     31.25
#
#    window_start_sec    start_unix      end_unix
# 0             175.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0      781.25  137.641972         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  192.320838  201.212956  ...      890.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  72.727273  90.909091    546.875    1031.25      5.5     187.5
#
#    window_start_sec    start_unix      end_unix
# 0             180.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  779.829545  207.69552         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  285.984457  301.003818  ...      828.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  81.818182  90.909091     531.25     1250.0     11.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             185.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN  HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  740.885417  62.30735         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD  HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN      94.34  98.93341  ...       793.75  58.333333
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  83.333333    609.375    828.125      6.0   109.375             190.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0   714.84375  96.347768         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  163.944086  171.939554  ...      784.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  83.333333  83.333333     593.75    890.625      4.0    78.125
#
#    window_start_sec    start_unix      end_unix
# 0             195.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  789.772727  206.150975         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  322.799038  340.244117  ...      890.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  81.818182  81.818182     593.75   1296.875      5.5    46.875
#
#    window_start_sec    start_unix      end_unix
# 0             200.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  769.886364  289.808236         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  442.990106  457.752947  ...      984.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  90.909091  90.909091    421.875   1296.875      5.5       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             205.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  701.923077  232.322746         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  428.122149  446.063628  ...       931.25
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  92.307692  92.307692    390.625    1031.25     13.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             210.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  610.491071  191.117378         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  239.957553  245.189853  ...       768.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  78.571429  92.857143     343.75    953.125      7.0    15.625
#
#    window_start_sec    start_unix      end_unix
# 0             215.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  652.901786  347.346709         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  388.407165  404.032719  ...        825.0
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  78.571429  92.857143     343.75   1546.875      7.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             220.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1128.90625  274.694179         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  365.581118  392.983949  ...      1256.25
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       75.0       75.0    578.125    1531.25      8.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             225.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    823.4375  247.606818         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  295.087822  312.966232  ...       1012.5
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       80.0       80.0     468.75    1218.75     10.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             230.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  727.864583  206.479978         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  280.973665  293.839143  ...       818.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  66.666667  83.333333      375.0     1187.5      6.0   296.875
#
#    window_start_sec    start_unix      end_unix
# 0             235.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  694.711538  248.089656         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  412.487176  430.465893  ...      771.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  84.615385  92.307692      375.0   1328.125     13.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             240.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  641.741071  157.860009         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  261.958576  272.551794  ...      734.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  92.857143  92.857143    359.375    921.875      7.0     375.0
#
#    window_start_sec    start_unix      end_unix
# 0             245.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  805.397727  282.925878         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  455.944889  477.138484  ...      953.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  81.818182  90.909091      500.0    1468.75     11.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             250.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  954.861111  356.257234         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  429.083382  458.134067  ...     1234.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  88.888889  88.888889      500.0   1546.875      4.5   421.875
#
#    window_start_sec    start_unix      end_unix
# 0             255.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  709.134615  209.197926         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  284.915352  296.974664  ...        887.5
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  92.307692  92.307692      312.5   1078.125     13.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             260.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  767.045455  315.953924         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  389.592385  410.583854  ...      890.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  81.818182  81.818182    328.125     1312.5      5.5   390.625
#
#    window_start_sec    start_unix      end_unix
# 0             265.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0     765.625  333.459079         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  545.574753  571.968913  ...      928.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  83.333333  83.333333      375.0     1500.0      6.0    343.75
#
#    window_start_sec    start_unix      end_unix
# 0             270.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  720.170455  293.937319         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  489.389368  514.808908  ...      796.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  72.727273  72.727273    390.625   1453.125      5.5     312.5
#
#    window_start_sec    start_unix      end_unix
# 0             275.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0     765.625  271.042678         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  467.422362  489.910634  ...        900.0
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  66.666667  83.333333    453.125   1453.125      4.0     250.0
#
#    window_start_sec    start_unix      end_unix
# 0             280.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0   699.21875  135.254948         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  188.562331  197.743395  ...       718.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  41.666667  83.333333    421.875    1031.25      3.0   296.875
#
#    window_start_sec    start_unix      end_unix
# 0             285.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0   746.09375  198.999294         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  204.974101  213.814035  ...      746.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  58.333333  91.666667      437.5   1171.875      6.0   234.375
#
#    window_start_sec    start_unix      end_unix
# 0             290.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  775.568182  266.659083         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD  HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  364.903134  380.0442  ...        750.0  45.454545
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  72.727273    609.375   1421.875      5.5       0.0             295.0
#
#      start_unix      end_unix
# 0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  821.022727  292.430851         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  328.013374  343.675023  ...     1046.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  36.363636  90.909091    609.375    1406.25     2.75    46.875
#
#    window_start_sec    start_unix      end_unix
# 0             300.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0     859.375  246.756301         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  328.050587  345.795681  ...     1046.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  72.727273  81.818182    515.625     1312.5      5.5   171.875
#
#    window_start_sec    start_unix      end_unix
# 0             305.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  751.302083  198.813322         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  274.096203  286.821395  ...       968.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  91.666667  91.666667    484.375    1093.75      6.0    46.875
#
#    window_start_sec    start_unix      end_unix
# 0             310.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  697.916667  142.791601         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  239.989568  251.487055  ...      759.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       75.0  91.666667    484.375    984.375      6.0     250.0
#
#    window_start_sec    start_unix      end_unix
# 0             315.0  1.594140e+09  1.594140e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  647.321429  169.034025         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  276.536355  287.131348  ...      803.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  71.428571  78.571429    390.625    921.875      7.0    218.75
#
#    window_start_sec    start_unix      end_unix
# 0             320.0  1.594140e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  660.714286  201.54047         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  275.413533  286.044646  ...       781.25
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN   HRV_HTI  HRV_TINN  \
# 0  57.142857  64.285714      375.0   1015.625  4.666667     250.0
#
#    window_start_sec    start_unix      end_unix
# 0             325.0  1.594140e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  709.134615  142.284545         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  195.62475  203.95645  ...      796.875  61.538462
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  76.923077      437.5   1015.625      6.5    218.75             330.0
#
#      start_unix      end_unix
# 0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  729.166667  260.464011         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  398.082228  416.990878  ...      853.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  91.666667  91.666667      312.5   1328.125     12.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             335.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  724.759615  288.148785         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  457.770725  478.094981  ...        837.5
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  84.615385  92.307692      312.5   1328.125     13.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             340.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  789.772727  268.583127         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  390.74998  408.50071  ...     1109.375  72.727273
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  90.909091     406.25   1203.125     11.0       0.0             345.0
#
#      start_unix      end_unix
# 0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0       687.5  243.820102         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  318.752553  325.907914  ...       906.25
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  69.230769  76.923077      375.0    1156.25      6.5    531.25
#
#    window_start_sec    start_unix      end_unix
# 0             350.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  622.767857  183.946408         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  294.01456  305.956124  ...        750.0  85.714286
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  92.857143     343.75    984.375      7.0   265.625             355.0
#
#      start_unix      end_unix
# 0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  614.955357  169.355123         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  245.221765  254.448847  ...      703.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  78.571429  92.857143     343.75      937.5      7.0   109.375
#
#    window_start_sec    start_unix      end_unix
# 0             360.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  821.022727  288.903135         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  195.406228  202.147756  ...     1171.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  63.636364  90.909091      437.5    1218.75      5.5    406.25
#
#    window_start_sec    start_unix      end_unix
# 0             365.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    864.0625  335.689104         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  520.155809  546.769583  ...       1225.0
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       70.0       80.0     468.75    1281.25      5.0   109.375
#
#    window_start_sec    start_unix      end_unix
# 0             370.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],     HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1050.347222  334.27804         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  458.048414  484.190453  ...       1262.5
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  66.666667  88.888889     468.75   1390.625      9.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             375.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0     953.125  278.92558         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  416.601557  438.854241  ...     1221.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       90.0       90.0    578.125     1375.0     10.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             380.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  849.431818  165.252046         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  212.235589  223.22433  ...      984.375  63.636364
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  90.909091    671.875   1203.125     11.0       0.0             385.0
#
#      start_unix      end_unix
# 0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  691.105769  185.443787         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  227.055857  237.011684  ...       781.25
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN   HRV_HTI  HRV_TINN  \
# 0  69.230769  92.307692      312.5     1000.0  4.333333   390.625
#
#    window_start_sec    start_unix      end_unix
# 0             390.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  965.277778  655.402065         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  747.00329  750.276061  ...     1015.625  77.777778
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  88.888889      562.5   2609.375      4.5   140.625             395.0
#
#      start_unix      end_unix
# 0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  680.989583  100.702948         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  136.297036  142.755328  ...       781.25
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  58.333333  83.333333      562.5     843.75      6.0    15.625
#
#    window_start_sec    start_unix      end_unix
# 0             400.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  664.663462  213.059865         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  299.059942  310.921677  ...        862.5
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  76.923077  92.307692      312.5     1000.0     13.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0             405.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  596.679688  213.723405         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  313.124376  323.762812  ...       843.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       87.5      93.75      312.5     1000.0      8.0   171.875
#
#    window_start_sec    start_unix      end_unix
# 0             410.0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  719.951923  365.018056         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  444.92399  464.707951  ...      890.625  84.615385
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN   HRV_HTI  HRV_TINN  window_start_sec  \
# 0  92.307692      312.5     1687.5  4.333333   171.875             415.0
#
#      start_unix      end_unix
# 0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  963.541667  437.43024         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  552.648099  587.90592  ...     1265.625  88.888889
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  88.888889    421.875     1687.5      9.0       0.0             420.0
#
#      start_unix      end_unix
# 0  1.594141e+09  1.594141e+09
#
# [1 rows x 28 columns],    HRV_MeanNN  HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# ...
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       40.0       70.0    578.125   1484.375      5.0    15.625
#
#    window_start_sec    start_unix      end_unix
# 0            7655.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    889.0625  292.08025         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  410.170717  430.523177  ...     1140.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       80.0       90.0    578.125   1484.375     10.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7660.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  791.193182  207.909133         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  374.120061  394.326215  ...       1000.0
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  81.818182  81.818182    484.375    1156.25      5.5     93.75
#
#    window_start_sec    start_unix      end_unix
# 0            7665.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  833.806818  222.322692         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  344.955273  361.804889  ...     1078.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  81.818182  81.818182      500.0    1156.25     11.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7670.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  848.011364  218.089506         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  284.78679  299.73947  ...       1000.0  81.818182
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  81.818182      500.0    1156.25      5.5     125.0            7675.0
#
#      start_unix      end_unix
# 0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  735.576923  249.956176         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  310.900856  324.722506  ...      984.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  76.923077  76.923077      375.0   1171.875      6.5     250.0
#
#    window_start_sec    start_unix      end_unix
# 0            7680.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  716.346154  296.315684         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  453.147449  473.279489  ...      815.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  84.615385  84.615385    390.625     1500.0     13.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7685.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0     846.875  380.372396         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  457.652193  485.326127  ...      1143.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       80.0       90.0    390.625   1546.875      5.0     93.75
#
#    window_start_sec    start_unix      end_unix
# 0            7690.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    695.3125  188.149915         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  236.496084  247.878069  ...        725.0
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  58.333333       75.0     531.25   1203.125      6.0     31.25
#
#    window_start_sec    start_unix      end_unix
# 0            7695.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0       925.0  373.826288         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  420.490269  429.118942  ...      1268.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       70.0       90.0    546.875   1578.125     10.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7700.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  729.166667  357.134402         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  352.76782  367.454871  ...       956.25  83.333333
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  91.666667    328.125     1562.5     12.0       0.0            7705.0
#
#      start_unix      end_unix
# 0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  645.833333  267.443087         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  391.957953  410.559528  ...      915.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       75.0  83.333333    328.125   1109.375      6.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7710.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],     HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1005.859375  374.808126         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  532.332144  573.521731  ...      1293.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       87.5       87.5    328.125    1468.75      8.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7715.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  869.318182  340.98839         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  357.331145  364.34516  ...      1218.75  72.727273
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  90.909091      312.5   1359.375     11.0       0.0            7720.0
#
#      start_unix      end_unix
# 0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0   746.09375  198.552669         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  266.958551  279.984527  ...        862.5
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       75.0  83.333333      562.5   1265.625      6.0     93.75
#
#    window_start_sec    start_unix      end_unix
# 0            7725.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  782.670455  323.588774         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD  HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  478.798545  497.9341  ...        812.5  81.818182
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  90.909091    359.375   1390.625      5.5   390.625            7730.0
#
#      start_unix      end_unix
# 0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    885.9375  425.941691         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  369.865016  390.737831  ...     1165.625
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       90.0       90.0    359.375     1750.0     10.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7735.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],     HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1091.796875  294.863664         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  511.107101  552.037706  ...      1118.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       62.5       75.0    828.125     1750.0      4.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7740.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1003.90625  277.34768         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  383.097106  411.990125  ...      1118.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       62.5       75.0    484.375     1437.5      4.0    593.75
#
#    window_start_sec    start_unix      end_unix
# 0            7745.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],     HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1194.196429  618.774801         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  849.804665  907.972501  ...     1428.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  85.714286  85.714286      312.5     2312.5      7.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7750.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    757.8125  271.492678         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  322.461954  337.803683  ...      928.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  66.666667  91.666667      312.5   1390.625      6.0     625.0
#
#    window_start_sec    start_unix      end_unix
# 0            7755.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  630.208333  225.707799         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD  HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  383.142624  397.5789  ...        750.0  73.333333
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  93.333333    328.125    1218.75      7.5   140.625            7760.0
#
#      start_unix      end_unix
# 0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  706.730769  295.167364         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  444.054326  462.233748  ...     1028.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  69.230769  76.923077    328.125    1218.75      6.5   140.625
#
#    window_start_sec    start_unix      end_unix
# 0            7765.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0     878.125  243.936894         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  339.501843  359.978358  ...     1109.375
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       70.0       70.0     531.25     1125.0      5.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7770.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0   925.78125  307.748475         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  451.737407  487.878554  ...     1096.875
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       87.5       87.5    578.125     1500.0      8.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7775.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  751.420455  316.108428         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  478.492506  497.607121  ...     1078.125
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0  90.909091  90.909091    328.125    1281.25     11.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7780.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],     HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1072.265625  145.365894         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  193.45095  208.268219  ...     1196.875       75.0
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0       87.5     906.25    1281.25      4.0       0.0            7785.0
#
#      start_unix      end_unix
# 0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0    889.0625  471.142621         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD    HRV_SDSD  ...  HRV_Prc80NN  \
# 0         NaN         NaN  579.671355  607.619667  ...      1218.75
#
#    HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  \
# 0       90.0       90.0      375.0   1859.375      5.0       0.0
#
#    window_start_sec    start_unix      end_unix
# 0            7790.0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns],    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  751.302083  404.523118         NaN         NaN         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5   HRV_RMSSD   HRV_SDSD  ...  HRV_Prc80NN  HRV_pNN50  \
# 0         NaN         NaN  549.264261  575.91716  ...        812.5  91.666667
#
#    HRV_pNN20  HRV_MinNN  HRV_MaxNN  HRV_HTI  HRV_TINN  window_start_sec  \
# 0  91.666667      375.0   1859.375      6.0     250.0            7795.0
#
#      start_unix      end_unix
# 0  1.594148e+09  1.594148e+09
#
# [1 rows x 28 columns]]
# Saved 1559 rows to processed\BVP_15_1594140175.csv

# %%
all_bvp_paths[0]
bvp_raw = pd.read_csv(all_bvp_paths[0], header=None)
bvp_raw.iloc[1, 0]
# Out:
# 64.0

# %%
window_size = int(64 * 10)
start_sample = int(1227 * window_size * (1 - 0.5))
end_sample = start_sample + window_size

flagged_bvp = (bvp_raw[start_sample:end_sample])
flagged_bvp = np.array(flagged_bvp.iloc[:, 0].values)
print(np.std(flagged_bvp))
if np.std(flagged_bvp) < 0.01:
    print(f"Skipping window {i}: signal too flat (std={np.std(flagged_bvp):.5f})")
#save flagged_bvp to csv
# flagged_bvp.to_csv("flagged_bvp.csv", index=False, header=False)
# signals, info = nk.ppg_process(flagged_bvp, sampling_rate=64)
# features = nk.hrv_time(signals, sampling_rate=64, show=False)
# Out:
# 91.98466389275251
